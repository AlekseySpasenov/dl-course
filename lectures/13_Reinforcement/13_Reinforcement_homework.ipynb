# %% [markdown]
# ## Домашнее задание : "Обучение с подкреплением"

# %% [markdown]
# ФИО:

# %% [markdown]
# # Задание 1
#
# Обучите алгоритм Q-learning для сред FrozenLake-v1, в частности подберите оптимальную alpha. (1 балл)
#
# Опционально: Придумайте, как добиться от Q-learning таких же результатов как от Policy iteration на большой среде

# %% [markdown]
# # Задание 2
#
# Обучите алгоритм Deep Q-Learning (или AC) для среды https://ale.farama.org/environments/breakout . Продемонстрируйте, что для обученного агента растет время игры. (2 балла)
#
# Обучите единый алгоритм Deep Q-Learning (или AC) для сред https://ale.farama.org/environments/breakout и https://ale.farama.org/environments/pong/  (policy/qfunction-сеть должна иметь backbone и головы для каждой из сред). Продемонстрируйте, что для обученного агента растет время игры. (2 балла)
#
# За основу можно взять репозиторий: https://github.com/caspernorrbin/pong-dqn
