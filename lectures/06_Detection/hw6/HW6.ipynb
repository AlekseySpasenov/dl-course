# %% [markdown]
# # Домашнее задание №6

# %% [markdown]
# 1. Напишите функцию IoU `intersection_over_union()` в файле `hw_utils.py`. (_0,5 балла_)

# %% [markdown]
# 2. Напишите функцию NMS `non_max_suppression()` в файле `hw_utils.py`. (_1 балл_)

# %% [markdown]
# 3. Напишите функцию mAP в файле `hw_utils.py`. (_1 балл_)

# %% [markdown]
# 4. Попробуйте самостоятельно разобраться в архитектура YoloV1. Допишите инференс YoloV1, внедрив предыдущие функции в код (в файл `hw_utils.py`) и вычислите mAP. (_2,5 балла_)
